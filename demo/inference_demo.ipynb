# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv

# %%
config_file = '/home/jovyan/workspace/ml_mg/cbnetev2/configs/custom/htc_cbv2_swin_base_patch4_window7_mstrain_400-1400_giou_4conv1f_adamw_20e_coco.py'
# download the checkpoint from model zoo and put it in `checkpoints/`
# url: https://download.openmmlab.com/mmdetection/v2.0/faster_rcnn/faster_rcnn_r50_fpn_1x_coco/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
checkpoint_file = '/home/jovyan/workspace/ml_mg/cbnetev2/work_dirs/htc_cbv2_swin_base_patch4_window7_mstrain_400-1400_giou_4conv1f_adamw_20e_coco/latest.pth'

# %%
-s

# %%
# build the model from a config file and a checkpoint file
# model = init_detector(config_file, checkpoint_file, device='cuda:0')
model = init_detector(config_file, checkpoint_file, device='cpu')
# Out:
# /home/jovyan/workspace/ml_mg/cbnetev2/mmdet/core/anchor/builder.py:15: UserWarning: ``build_anchor_generator`` would be deprecated soon, please use ``build_prior_generator``
#   warnings.warn(
# Use load_from_local loader

# %%
import glob

path = "/home/jovyan/data/filtered-food2/*"
file_list = glob.glob(path)
file_list_py = [file for file in file_list if file.endswith(".jpg")]
print(file_list_py[:10])
# Out:
# ['/home/jovyan/data/filtered-food2/01bba6c8-e8b9-40df-9c5e-34b9f774ffc7.jpg', '/home/jovyan/data/filtered-food2/015c51c1-9a77-4260-a699-cd4d71f92d02.jpg', '/home/jovyan/data/filtered-food2/0123bf64-70f9-4bc1-a8c9-d50064ad5303.jpg', '/home/jovyan/data/filtered-food2/039e7101-a328-4e09-b270-a63be560246d.jpg', '/home/jovyan/data/filtered-food2/045b2318-a35e-49a5-a661-6c01eabc541c.jpg', '/home/jovyan/data/filtered-food2/01734058-e43b-449f-88ef-31cbfea86320.jpg', '/home/jovyan/data/filtered-food2/04b46dfe-0a42-47e7-b248-fe7ac37e1acf.jpg', '/home/jovyan/data/filtered-food2/0593b77a-6f85-4f5a-9e5f-31fb475db6e0.jpg', '/home/jovyan/data/filtered-food2/07dcd3d0-9570-46f4-85bd-d3568ab0a1e9.jpg', '/home/jovyan/data/filtered-food2/039f6642-6d38-47dc-8390-29ff715c9bb8.jpg']

# %%
# test a single image
# img = 'demo.jpg'

for img in file_list_py[:1]:
    result = inference_detector(model, img)
    show_result_pyplot(model, img, result)
# Out:
# /home/jovyan/workspace/ml_mg/cbnetev2/mmdet/datasets/utils.py:64: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   warnings.warn(

# %%
# show the results
show_result_pyplot(model, img, result)
